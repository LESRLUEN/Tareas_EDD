# %% [markdown]
# <a href="https://colab.research.google.com/github/LESRLUEN/Tareas_EDD/blob/main/Tarea_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class StackADT:
    def __init__(self):
        self.__data = list()

    def is_empty(self):
        return len(self.__data) == 0
    
    def get_length(self):
        return len(self.__data)

    def pop(self):
        if self.is_empty():
            print("Pila vacíar")
        else:
            return self.__data.pop()

    def peek(self):
        if self.is_empty():
            print("Pila vacía")
        else :
            return self.__data[-1]
    
    def push(self, value):
        self.__data.append(value)

    def to_string(self):
        for item in self.__data[::-1]:
            print(f'| { item } |')

# %%
entrada= open('archivo.txt', 'rt') 
codigo = entrada.read()
pilaControl=StackADT()

pilaControl.push("#") 

for letra in codigo:
    if letra == '{':
        pilaControl.push('{')  
        if pilaControl.peek() == '#':
            pilaControl.push('{')
            break 
        else:
            basura = pilaControl.pop()
    elif letra == '(':
        pilaControl.push('(') 
        if pilaControl.peek() == '#':
            pilaControl.push('(')
            break 
        else:
            basura = pilaControl.pop() 
    else:
        pass
 
if pilaControl.peek() == '#':
    print("El código que se leyó está balanceado.")
else :
    print("El código que se leyó no está balanceado en llaves {}, () de manera correcta")
print("")
print("El codigo que se ingreso es el siguiente: ")
print("")
print(codigo)
# Out:
# El código que se leyó está balanceado.
#
# El codigo que se ingreso es el siguiente:
#
# package calculadora;
# import java.util.Scanner; // Importación de la clase Scanner.
#
# public class TestCalculadora{
#   public static void main(String[] args) {
#         Scanner sc = new Scanner(System.in);
#         double res = 0;
#         String operacion;
#         boolean comprobar = false;
#
#         do{
#             //Verificación de los datos puestos por el usuario del número 1.
#             /* Con matches, hay una condición de que dígitos primero puede
# ...
